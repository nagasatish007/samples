# %% [markdown]
# ![Module 1: Hello Agent](../images/module-1-hello.svg)
#
# # Module 1: Hello Agent
#
# > 20 lines of Python become a working agent. The simplest possible Strands setup — one model, one tool, `agent(query)`.
#
# 💻 Standalone script: `code/step-00-hello/agent.py`
# 🔗 Sample: https://github.com/strands-agents/samples/tree/main/python/01-learn/18-self-improving-agents
#
# ---

# %% [markdown]
# # AIM308 — Module 0: Hello AgentThe minimum viable Strands agent. Run cells top-to-bottom.

# %% [markdown]
# ## Verify AWS access

# %%
# !aws sts get-caller-identity

# %% [markdown]
# ## Configure model + region
#
# We use Claude Sonnet 4.5 on Amazon Bedrock in `us-east-1`. Make sure you have [model access](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access-modify.html) enabled.

# %%
import os
import boto3
ssm = boto3.client('ssm')
MODEL_ID = ssm.get_parameter(Name='/aim302/model-id')['Parameter']['Value']  # Claude Sonnet 4.5
REGION = ssm.get_parameter(Name='/aim302/region')['Parameter']['Value']
os.environ["STRANDS_MODEL_ID"] = MODEL_ID
os.environ["AWS_REGION"] = REGION
os.environ["BYPASS_TOOL_CONSENT"] = os.getenv("BYPASS_TOOL_CONSENT", "true")
os.environ["STRANDS_TOOL_CONSOLE_MODE"] = "enabled"
print(f"Model:  {MODEL_ID}")
print(f"Region: {REGION}")

# %% [markdown]
# ## Install Strands (first time only)

# %%
# %pip install -q strands-agents strands-agents-tools

# %% [markdown]
# ## The agent

# %%
from strands import Agent
from strands_tools import shell
agent = Agent(
    model=MODEL_ID,
    tools=[shell],
    system_prompt="You are a helpful assistant. Use the shell tool when useful. Be concise."
)

# %% [markdown]
# ## Ask it things

# %%
agent("hello, introduce yourself")

# %%
agent("what files are in this directory?")

# %% [markdown]
# ### What just happened?Claude decided to call `shell(ls)` on its own. That's Strands' model-first philosophy.

# %% [markdown]
# Next: **[01_self_extending.ipynb](01_self_extending.ipynb)**
